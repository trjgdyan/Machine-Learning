# %% [markdown]
# <a href="https://colab.research.google.com/github/trjgdyan/Machine-Learning/blob/main/Week1_Tugas_Kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Tri Jagad Ariyani
#
# NIM : 2141720049

# %% [markdown]
# # Deskripsi Tugas
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
# 2. Lakukan proses encoding pada kolom "diagnosis".
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %%
from google.colab import drive

#accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/Machine Learning/wbc.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#NOMOR 1
# Variabel yang tidak dapat digunakan
data = data.drop(['id', 'radius_se', 'texture_se', 'perimeter_se',
    'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se',
    'symmetry_se', 'radius_worst', 'texture_worst',
    'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst',
    'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst'], axis=1)

# Variabel yang dapat digunakan
variabel_dapat_digunakan = [
    'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
    'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean'
]

data = data[variabel_dapat_digunakan]

# Menampilkan data yang sudah dipisahkan
data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# 0         0.2419                 0.07871
# ...

# %%
# NOMOR 2
le = LabelEncoder() # membuat objek dari LabelEncoder
data['diagnosis'] = le.fit_transform(data['diagnosis']) # proses encoding
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# 0         0.2419                 0.07871
# ...

# %%
# NOMOR 3
from sklearn.preprocessing import StandardScaler
std = StandardScaler() #Inisialisasi Standarisasi

#Proses Standarisasi
data['radius_mean'] = std.fit_transform(data[['radius_mean']])
data['texture_mean'] = std.fit_transform(data[['texture_mean']])
data['perimeter_mean'] = std.fit_transform(data[['perimeter_mean']])
data['area_mean'] = std.fit_transform(data[['area_mean']])
data['smoothness_mean'] = std.fit_transform(data[['smoothness_mean']])
data['compactness_mean'] = std.fit_transform(data[['compactness_mean']])
data['concavity_mean'] = std.fit_transform(data[['concavity_mean']])
data['concave points_mean'] = std.fit_transform(data[['concave points_mean']])
data['symmetry_mean'] = std.fit_transform(data[['symmetry_mean']])
data['fractal_dimension_mean'] = std.fit_transform(data[['fractal_dimension_mean']])
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097064     -2.073335        1.269934   0.984375
# 1          1     1.829821     -0.353632        1.685955   1.908708
# 2          1     1.579888      0.456187        1.566503   1.558884
# 3          1    -0.768909      0.253732       -0.592687  -0.764464
# 4          1     1.750297     -1.151816        1.776573   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         1.568466          3.283515        2.652874             2.532475
# 1        -0.826962         -0.487072       -0.023846             0.548144
# 2         0.942210          1.052926        1.363478             2.037231
# 3         3.283553          3.402909        1.915897             1.451707
# 4         0.280372          0.539340        1.371011             1.428493
#
#    symmetry_mean  fractal_dimension_mean
# 0       2.217515                2.255747
# ...

# %%
# NOMOR 4

# Split data
from sklearn.model_selection import train_test_split

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 8:2
data_train, data_unseen = train_test_split(data, test_size=0.2, random_state=0, stratify=data['diagnosis'])

# Split lagi antara validasi dan testing
data_val, data_test = train_test_split(data_unseen, test_size=0.5, random_state=0, stratify=data_unseen['diagnosis'])

# Cek masing-masing ukuran data

print(f'Jumlah label data asli:\n{data.diagnosis.value_counts()}')
print(f'Jumlah label data train:\n{data_train.diagnosis.value_counts()}')
print(f'Jumlah label data val:\n{data_val.diagnosis.value_counts()}')
print(f'Jumlah label data test:\n{data_test.diagnosis.value_counts()}')
# Out:
# Jumlah label data asli:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64
# Jumlah label data train:
# 0    285
# 1    170
# Name: diagnosis, dtype: int64
# Jumlah label data val:
# 0    36
# 1    21
# Name: diagnosis, dtype: int64
# Jumlah label data test:
# 0    36
# 1    21
# Name: diagnosis, dtype: int64
